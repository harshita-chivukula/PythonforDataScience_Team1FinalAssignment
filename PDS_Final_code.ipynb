# %% [markdown]
# # Dataset
#
# In this final project, you will analyze the performance of the 10 big fast-food companies in the stock market over the years. To do so, you will have to form groups of 5 people and give answers to all the questions provided below.
#
# Each dataset contains 10 CSV files corresponding to a different fast-food company’s stock:
#
# - **BRK-A**: Berkshire Hathaway Inc.
# - **DNUT**: Krispy Kreme, Inc.
# - **DPZ**: Domino’s Pizza, Inc.
# - **LKNCY**: Luckin Coffee Inc.
# - **MCD**: McDonald’s Corporation
# - **PZZA**: Papa John’s International, Inc.
# - **QSR**: Restaurant Brands International, Inc.
# - **SBUX**: Starbucks Corporation
# - **WEN**: The Wendy’s Corporation
# - **YUM**: Yum! Brands, Inc.
#
# ## Columns
#
# The datasets contain the following columns:
#
# - **Date**: Trading date
# - **Open**: Opening price
# - **High**: Highest price during session
# - **Low**: Lowest price during session
# - **Close**: Closing price
# - **Adj Close**: Closing price adjusted for dividends and stock splits
# - **Volume**: Number of shares traded during the session

# %% [markdown]
# # Exercises
#
# You will have to give answers to the following 10 exercises (1 point each):

# %% [markdown]
# **Preprocessing steps**

# %%
# Impoprt all the libraries necesaires for the project
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import datetime

# %%
# Importing the 10 datasets for the exercises
# Create a dictionary to store all of them
all_datasets = {}
databases_path = './Databases' # The path where the datasets are located 

# Here we use for loop to iterate over the folder where the datasets are, extract them and store them in a dictionary. 
for database in os.listdir(databases_path):
    database_name = database.split('.')[0]
    df = pd.read_csv(os.path.join(databases_path, database))
    all_datasets[database_name] = df

# %%
# Preprocessing steps for each dataset
# For faster pre-processing, we use a for loop to filter and clean each dataset at a time.
for name, dataset in all_datasets.items():
    # 1. Change the Date column to a datetime object and drop the duplicates. There are no missing values in Date so we do not remove them
    dataset['Date'] = pd.to_datetime(dataset['Date'], errors='coerce')
    dataset = dataset.drop_duplicates(subset='Date', keep='first') #Here we remove the duplicate values in Date this is the distribution (SBUX 4, DPZ 4, MCD 4, LKNCY 4, QSR 0, WEN 4, PZZA 3, YUM 4, BRK-A 4, DNUT 3)

    # 2. Sort by ‘Date’ for time consistency
    dataset = dataset.sort_values(by='Date')

    # 3. As the date is already clean, we only focus on the other numeric columns by storing them in a variable
    numeric_columns = dataset.select_dtypes(include='number').columns

    # 4. Here we handle missing values by column and using .ffill().bfill() which enters the NaN values with the next or last value of the column.
    for col in numeric_columns:
        dataset[col] = dataset[col].ffill().bfill()

    # 5. After dealing with all missing values, we focus on removing outliers. There are outliers in all databases except QSR, and in all columns except Volume and Date.  
    if name != 'QSR':  # As explained above, we exclude ‘QSR’ from cleaning and filtering.
        for col in numeric_columns.drop(['Volume'], errors='ignore'): #We also delete the Volume column as it is already OK. 
            quantile_97 = dataset[col].quantile(0.97) #To remove outliers, we remove all values that are beyond the 97th quantile. 
            dataset[col] = dataset[col].mask(dataset[col] > quantile_97) #In order not to lose data, instead of deleting them, we decided to transform them into NaN values to impute after 

    # 6. Here we fill the transformed values using the same method as before (.ffill().bfill()).
    for col in numeric_columns:
        dataset[col] = dataset[col].ffill().bfill()

    # 7. Finally, we update each pre-processed dataset in the dictionary created earlier.
    all_datasets[name] = dataset

# %% [markdown]
# 1. **For each dataset**:
#    - Print the number of rows and columns.
#    - Display the column names and their data types.

# %%
# To print the number of rows and columns we use a for loop that iterates over each data set and then displays the column names and their data types using .dtypes.
for name, dataset in all_datasets.items():
    print(f'The number of rows for the {name} dataset is {dataset.shape[0]} and the number of columns is {dataset.shape[1]}') 
    print(f'For {name} the columns are:')
    print(dataset.dtypes)
# Out:
# The number of rows for the SBUX dataset is 8117 and the number of columns is 7
# For SBUX the columns are:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume              float64
# dtype: object
# The number of rows for the DPZ dataset is 5083 and the number of columns is 7
# For DPZ the columns are:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume              float64
# dtype: object
# The number of rows for the MCD dataset is 14652 and the number of columns is 7
# For MCD the columns are:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume              float64
# ...

# %% [markdown]
# 2. **Extract all rows where the date is in the year 2023**:
#    - Print the number of rows.
#    - Visualize the Close price trend for this period.

# %%
# Create a variable to store the rows from 2023
total_rows_2023 = 0

# Use a for loop to iterate over the dataset dictionary and filter the rows by 2023, then add them, count the length and add it to a variable calculating the total rows. 
for name, dataset in all_datasets.items():
    rows_in_2023 = dataset[dataset['Date'].dt.year == 2023]  # Filter rows for 2023
    num_rows = len(rows_in_2023)
    print(f'The company {name} has {num_rows} rows in 2023.')  # Print number of rows for each company
    total_rows_2023 += num_rows  # Update the total row count

print(f'The total number of rows where the year is 2023 is {total_rows_2023}') # Print the total number of rows in 2023

# When plotting all the companies, we noticed that there is one with a big price difference (BRK-A) so plotting them together to see the trends distorts the whole chart.
# For this reason we decided to try different solutions:
    # 1. Plot individual graphs, however it is not really useful for identifying trends.
    # 2. Normalize the data to make companies comparable, but the graph is not really easy to decipher visually.
    # 3. Use two axes, so that the one on the left measures the price of the 9 other companies and the one on in the right measures the price of the BRK-A. However also showed some problems with distribution
    # 4. Finally we decided on a panel chart, one for BRK-A and one for the remaining companies. Wich is the code shown below. 

# Here we define the two plots one brka_plot and the other companies_plot, we use gridspec_kw to give more space to the plot for the 9 companies intead to BRK-A on a scale 1-3 and the constrained_layout to give more space to the plot.
fig, (brka_plot, companies_plot) = plt.subplots(2, 1, figsize=(12, 10), gridspec_kw={'height_ratios': [1, 3]}, constrained_layout=True)

# Panel for BRK-A. We select the rows that are from 2023 and for BRK-A and plot the graph
rows_in_2023_for_brk = all_datasets['BRK-A'][all_datasets['BRK-A']['Date'].dt.year == 2023]
brka_plot.plot(rows_in_2023_for_brk['Date'], rows_in_2023_for_brk['Close'], label='BRK-A Close Prices', color='red', linewidth=1.5, alpha=0.7,)
# Details and costumitzation for the BRK-A plot 
brka_plot.set_title('BRK-A Close Prices (2023)', fontsize=16)
brka_plot.set_ylabel("Close Price", fontsize=14)
brka_plot.legend(fontsize=10, loc='upper left')
brka_plot.grid(True, linestyle='--', alpha=0.3)

# Plot for the other companies here we do exactly the same for the BRK-A chart, but for the other 9 companies we use a loop to iterate over the dictionary.
for name, dataset in all_datasets.items(): 
    if name != 'BRK-A':  # A conditional to not use BRK-A for this plot
        rows_in_2023_rest_companies = dataset[dataset['Date'].dt.year == 2023]
        companies_plot.plot(rows_in_2023_rest_companies['Date'], rows_in_2023_rest_companies['Close'], label=f'{name} Close Prices', linewidth=1.5, alpha=0.8, )
# Details and costumitzation for the companies plot 
companies_plot.set_title('Companies Close Prices (2023)', fontsize=16)
companies_plot.set_ylabel('Close Price', fontsize=14)
companies_plot.set_xlabel('Date', fontsize=14)
companies_plot.legend(title='Company', fontsize=10, loc='upper left')
companies_plot.grid(True, linestyle='--', alpha=0.6)
# Show the plot
plt.show()
# Out:
# The company SBUX has 250 rows in 2023.
# The company DPZ has 250 rows in 2023.
# The company MCD has 250 rows in 2023.
# The company LKNCY has 250 rows in 2023.
# The company QSR has 250 rows in 2023.
# The company WEN has 250 rows in 2023.
# The company PZZA has 250 rows in 2023.
# The company YUM has 250 rows in 2023.
# The company BRK-A has 250 rows in 2023.
# The company DNUT has 250 rows in 2023.
# The total number of rows where the year is 2023 is 2500

# %% [markdown]
# 3. **For each company**:
#    - Find the day with the highest Close price and display it alongside the price.

# %%
# Use a loop over the dictionary to get the maximum value of the closing price and its index, so that we can also know the day when the price reached its maximum.
for name, dataset in all_datasets.items():
    max_close_price = dataset['Close'].max()
    max_close_price_index = dataset['Close'].idxmax()
    day_max_close_price = dataset.loc[max_close_price_index, 'Date']
    visual_date = day_max_close_price.strftime('%Y-%m-%d')
    print(f'For the company {name}, the day with the highest Close price was {visual_date}, with a price of {max_close_price:.2f}')
# Out:
# For the company SBUX, the day with the highest Close price was 2021-04-16, with a price of 118.34
# For the company DPZ, the day with the highest Close price was 2021-12-08, with a price of 534.17
# For the company MCD, the day with the highest Close price was 2024-09-19, with a price of 293.85
# For the company LKNCY, the day with the highest Close price was 2020-01-14, with a price of 45.80
# For the company QSR, the day with the highest Close price was 2024-03-13, with a price of 82.75
# For the company WEN, the day with the highest Close price was 1993-09-07, with a price of 30.50
# For the company PZZA, the day with the highest Close price was 2021-11-17, with a price of 129.64
# For the company YUM, the day with the highest Close price was 2024-04-03, with a price of 139.01
# For the company BRK-A, the day with the highest Close price was 2024-08-02, with a price of 641435.00
# For the company DNUT, the day with the highest Close price was 2022-01-04, with a price of 18.48

# %% [markdown]
# 4. **Group the data by month**:
#    - Calculate the average Close price for each company.
#    - Plot these monthly averages for 3 companies and compare them.
#    - Justify the chart selection.

# %%
# Create a dictionary to store the monthly averages for each company
monthly_averages = {}

# Follows the same strategy as in previous exercises: 
# Use a for loop to iterate through each company's dataset and extract the required data
for name, dataset in all_datasets.items():
    monthly_avg = dataset.groupby(dataset['Date'].dt.month)['Close'].mean() # Group by months using the datetime library and calculate the average closing price
    # As the months are extracted as an index, we need to transform them to use strftime. 
    # For this, we use a lambda function that creates datetime objects by adding a dummy year and a dummy day. Since we are only extracting the month, the values for the other components (year and day) are irrelevant.
    monthly_avg.index = monthly_avg.index.map(lambda x: datetime(2000, x, 1).strftime('%B')) 
    monthly_averages[name] = monthly_avg
    # Print the monthly average closing price for each company
    print(f"Monthly Average Closing Prices for {name}:")
    print(monthly_avg)
    print("\n")

# Select three companies representing different fast food segments (e.g., pizza, burgers/fries, coffee) for diverse insights
selected_companies = list(monthly_averages.keys())[2:5]

plt.figure(figsize=(12, 6))  # Create a figure for the plot with specified dimension

# Iterate through the selected companies to extract and plot their monthly averages
for company in selected_companies: 
    selected_companies_monthly_avg = monthly_averages[company] # Extract monthly averages
    plt.plot(selected_companies_monthly_avg, label=company, marker='o', linewidth=2, alpha=0.8) # Characteristics of the plot
    # Annotate the maximum average value for each company for better interpretation of key data points
    max_month = selected_companies_monthly_avg.idxmax()
    max_value = selected_companies_monthly_avg.max()
    plt.annotate(f'{max_value:.2f}', xy=(max_month, max_value), xytext=(0, 5), textcoords='offset points', ha='center') # How annotations are represented in the chart

# Customize the plot with a title, labels, legend, and grid for better readability
plt.title('Average Closing Prices by Month', fontsize=16)
plt.xlabel('Months', fontsize=14)
plt.ylabel('Average Closing Price', fontsize=14)
plt.legend(title='Company', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# Monthly Average Closing Prices for SBUX:
# Date
# January      30.814184
# February     30.911568
# March        30.428386
# April        31.087961
# May          30.597661
# June         30.493265
# July         30.165947
# August       30.890926
# September    30.597588
# October      29.109170
# November     30.871270
# December     31.113001
# Name: Close, dtype: float64
#
#
# Monthly Average Closing Prices for DPZ:
# Date
# January      151.124307
# February     152.770495
# March        152.298676
# April        158.486949
# May          160.433208
# June         164.470634
# July         164.644367
# August       163.200471
# September    154.819218
# October      143.015456
# November     149.620681
# December     151.212659
# Name: Close, dtype: float64
#
#
# Monthly Average Closing Prices for MCD:
# Date
# January      49.501732
# February     50.743905
# March        49.965946
# April        51.366500
# May          51.990128
# June         51.413697
# ...

# %% [markdown]
# Justification of chart selection:
#
# We selected a line chart for this exercise to illustrate the monthly seasonality of stock prices, with months on the x-axis and average closing prices on the y-axis. Grouping by months provides a clearer visualization of seasonal patterns, which would be less meaningful if grouped by years. Additionally, we annotated peak average values to highlight the months when companies experience their highest stock prices. This approach effectively reveals patterns in stock price fluctuations, such as dips in May and peaks in August, which may reflect seasonal consumer behavior or industry-specific factors.

# %% [markdown]
# 5. **For each company**:
#    - Compute the yearly average of the Close price.
#    - Plot a comparison of yearly averages for all companies on a chart.
#    - Justify your chart selection.

# %%
# Create a dictionary to store the annual average closing prices of each company.
annual_avg_prices = {}

# Following a similar approach to the previous exercise, use a for loop and the datetime library to group by years.
for name, dataset in all_datasets.items():
    yearly_avg = dataset.groupby(dataset['Date'].dt.to_period('Y'))['Close'].mean()  # Group the data by year and transform it into PeriodIndex.
    annual_avg_prices[name] = yearly_avg

plt.figure(figsize=(12, 6))

# Plot yearly averages for each company
for company in annual_avg_prices:
    yearly_avg = annual_avg_prices[company]
    plt.plot(yearly_avg.index.to_timestamp(), yearly_avg, label=company)  # Here we transform PeriodIndex to Timestamp for Matplotlib compatibility.

# Details and customization for the plot 
plt.title('Average Yearly Closing Prices', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Closing Price (Log Scale)', fontsize=14)
plt.yscale('log')  # Use a logarithmic scale to show exponential growth and make the companies comparable.
plt.grid(True, linestyle='--', alpha=0.7) 
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.legend(title='Company', fontsize=12)
plt.tight_layout() 
plt.show()

# %% [markdown]
# Justification of chart selection:
#
# To illustrate the average annual growth in a single graph, we chose to group all the companies in a line graph. To make the data comparable and enable the analysis of both individual company growth and overall market trends, we used a logarithmic scale to represent the growth over time. This approach accounts for the significant price differences among companies. Other options, such as a histogram, were considered but did not present the results as effectively as this line graph.

# %% [markdown]
# 6. **For each company**:
#    - Create a plot showing the range of prices for each month.
#    - Justify the chart selection.

# %%
# After trying 5 options, we decided to use a boxplot with Seaborn. 
boxplot_data = []

# First, we extract all the necessary data by grouping by month using the datetime library. 
for name, dataset in all_datasets.items():
    dataset_grouped = dataset.groupby(dataset['Date'].dt.month)['Close']
    for month, values in dataset_grouped:
        boxplot_data.extend([[month, value, name] for value in values])

# To work with Seaborn, it is necessary to use Pandas, so in the next step, we convert the data into a Pandas DataFrame. 
boxplot_df = pd.DataFrame(boxplot_data, columns=['Month', 'Close', 'Company'])

# Here we use a similar function as in the previous exercise to map the months to their names. 
boxplot_df['Month'] = boxplot_df['Month'].apply(lambda x: datetime(2000, x, 1).strftime("%B"))

# For comparability and to gain insights, we decided to create subplots for 10 boxplots in a single figure.
fig, axes = plt.subplots(2, 5, figsize=(20, 10), sharey=True)
axes = axes.flatten()

# Use a for loop to iterate over each company's data and plot each graph. 
for idx, company in enumerate(boxplot_df['Company'].unique()):
    ax = axes[idx]
    company_data = boxplot_df[boxplot_df['Company'] == company]
    # Use Seaborn boxplot for better visualization. 
    sns.boxplot(x='Month', y='Close', hue='Month', data=company_data, showfliers=True, ax=ax, palette='viridis', dodge=False)
    
    # Details and customization for each subplot. 
    ax.set_title(f'Company: {company}', fontsize=14)
    ax.set_xlabel("")
    ax.set_ylabel('Close Price', fontsize=12)
    ax.set_xticks(range(len(company_data['Month'].unique())))
    ax.set_xticklabels(company_data['Month'].unique(), rotation=45, fontsize=9)
    ax.grid(axis='y', linestyle='--', alpha=0.6)
    ax.set_yscale('log')  # Use log scale for comparability.

# Details and customization for the entire plot. 
fig.suptitle('Monthly Range of Closing Prices by Company', fontsize=14)
plt.tight_layout() 
plt.show()

# %% [markdown]
# Justification of chart selection:
#
# Here, we faced several challenges in plotting the price ranges by month while ensuring comparability across companies. After experimenting with different options and customizations, we ultimately decided on a boxplot constructed with 10 subplots, one for each company, and used a logarithmic scale to enhance comparability. To achieve this, we grouped the data by month.
#
# This approach allows the reader to observe how prices vary monthly and compare them across companies, offering both an industry-wide perspective and company-specific insights. Plotting individual graphics made comparison difficult, while combining everything into a single plot compromised visibility. The boxplot proved to be the best choice for analyzing price ranges, especially when compared to alternatives like strip plots. While strip plots can highlight distributions, boxplots are more effective for studying ranges, which is our primary focus here.

# %% [markdown]
# 7. **Create a plot showing the relationship between trading volume and the Close price**:
#    - Select one company.
#    - Add insights about the pattern.
#    - Justify your chart selection.

# %%
# We chose McDonald's because of the historical insights and financial stability derived from the longevity of the company.
selected_company = "MCD"
# Extract the dataset for MCD.
company_data = all_datasets[selected_company]

# Create a scatter plot to visualize the relationship between trading volume and closing price.
plt.figure(figsize=(10, 6))
plt.scatter(company_data['Volume'], company_data['Close'], color='green', alpha=0.6, edgecolor='black', s=20)

# Add plot details and personalization for better interpretation.
plt.title(f'Trading Volume vs Closing Price for {selected_company}', fontsize=14)
plt.xlabel('Trading Volume', fontsize=14)
plt.ylabel('Closing Price', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# Justification for plot selection:
#
# The scatter chart was chosen because it effectively visualizes the relationship between two continuous variables: trading volume and closing price. This chart type allows us to identify potential patterns, clusters, or correlations between the variables. The use of green dots with a simple layout ensures clarity and makes overlapping points easy to interpret.
#
# Brief insights about the pattern:
# 1.	Volume Concentration at Low Levels: Most trading activity is concentrated at lower volumes, with closing prices spread across a wide range between $50 and $250. This suggests McDonald’s stock performance is relatively stable even with varying volumes of trading.
# 2.	Outliers in High Volumes: A few outlier points with unusually high trading volumes and varied closing prices are evident. These are likely tied to significant market events, such as earnings announcements, corporate news, or broader market movements impacting trading behavior.

# %% [markdown]
# 8. **For each company**:
#    - Identify the month with the highest total trading volume.
#    - Display the results in a summary table, showing the month and total volume.

# %%
# Create a dictionary to store highest voluem for month for each company 
highest_monthly_volume = {}

# Use a for loop to group by month and find the index of the month of maximum volume and its volume and finally store it in a data frame.
for name, dataset in all_datasets.items():
    monthly_volume = dataset.groupby(dataset['Date'].dt.to_period('M'))['Volume'].sum()
    highest_volume_month = monthly_volume.idxmax()
    highest_volume_value = monthly_volume.max()
    highest_monthly_volume[name] = pd.DataFrame({
        'Month': [highest_volume_month],
        'Total Volume': [highest_volume_value]
    })
# Create a summary table for the months and company 
summary_table = pd.concat(highest_monthly_volume, names=['Company'])
summary_table.reset_index(level=1, drop=True, inplace=True)
# Apply styling to the summary table
styled_summary = summary_table.style.format({
    'Total Volume': '{:,.0f}',  # Add thousand separators and remove decimals
    'Month': lambda x: x.strftime('%B %Y')  # Format Month as "Month Year"
}).set_caption("Summary Table of Highest Monthly Trading Volumes").set_table_styles([
    {'selector': 'caption', 'props': 'caption-side: top; font-size: 16px; font-weight: bold;'},
    {'selector': 'th', 'props': 'font-size: 14px; font-weight: bold;'},
    {'selector': 'td', 'props': 'font-size: 12px; text-align: center;'}
])

# Display the styled table
styled_summary
# Out:
# <style type="text/css">
# #T_e882f caption {
#   caption-side: top;
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_e882f th {
#   font-size: 14px;
#   font-weight: bold;
# }
# #T_e882f td {
#   font-size: 12px;
#   text-align: center;
# }
# </style>
# <table id="T_e882f">
#   <caption>Summary Table of Highest Monthly Trading Volumes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e882f_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_e882f_level0_col1" class="col_heading level0 col1" >Total Volume</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Company</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e882f_level0_row0" class="row_heading level0 row0" >SBUX</th>
#       <td id="T_e882f_row0_col0" class="data row0 col0" >July 1999</td>
# ...

# %% [markdown]
# 9. **Merge the datasets for all companies**:
#    - Create a single dataset, one for each year.
#    - Print the structure of the combined dataset, ensuring proper alignment and handling of missing values.

# %%
# The clean-up steps have already been performed in the previous steps, so the data is clean and ready for merging.
# Create a list for storing all datasets for future concatenation
list_datasets = []

# Use a for loop over the dictionary we have been using throughout the project to add a Company column in each dataset
for name, dataset in all_datasets.items():
    dataset["Company"] = name  # Add the Company column
    dataset["Year"] = dataset["Date"].dt.year  # Add the Year column
    list_datasets.append(dataset)

# Combine all the datasets into one
merged_data = pd.concat(list_datasets, ignore_index=True)

# Print the structure of the combined dataset
print("Shape of merged dataset:", merged_data.shape)

# Create a dictionary to store all the datasets for each year
datasets_by_year = {}

# Use a for loop to go through each year and store the rows from that year in a single dataset
for year in merged_data["Year"].unique():
    datasets_by_year[year] = merged_data[merged_data["Year"] == year]
    print(f"Dataset for year {year} has shape: {datasets_by_year[year].shape}")
# Out:
# Shape of merged dataset: (69549, 9)
# Dataset for year 1992 has shape: (893, 9)
# Dataset for year 1993 has shape: (1157, 9)
# Dataset for year 1994 has shape: (1260, 9)
# Dataset for year 1995 has shape: (1260, 9)
# Dataset for year 1996 has shape: (1270, 9)
# Dataset for year 1997 has shape: (1339, 9)
# Dataset for year 1998 has shape: (1512, 9)
# Dataset for year 1999 has shape: (1512, 9)
# Dataset for year 2000 has shape: (1512, 9)
# Dataset for year 2001 has shape: (1488, 9)
# Dataset for year 2002 has shape: (1512, 9)
# Dataset for year 2003 has shape: (1512, 9)
# Dataset for year 2004 has shape: (1633, 9)
# Dataset for year 2005 has shape: (1764, 9)
# Dataset for year 2006 has shape: (1757, 9)
# Dataset for year 2007 has shape: (1757, 9)
# Dataset for year 2008 has shape: (1771, 9)
# Dataset for year 2009 has shape: (1764, 9)
# Dataset for year 2010 has shape: (1764, 9)
# Dataset for year 2011 has shape: (1764, 9)
# Dataset for year 2012 has shape: (1750, 9)
# ...

# %% [markdown]
# 10. **For each company**:
#     - Calculate the spread between the High and Low prices for each day.
#     - Compute the average spread for each company.
#     - Visualize the result in a chart and justify the chart selection.
#     - Interpret which companies exhibit the largest spreads and why this might happen.

# %%
# We use the merged data set to calculate the spread. To do that we add a column that is the diference between the highest value - the lowest value for each day 
merged_data['Spread'] = merged_data['High'] - merged_data['Low']

# Once the column is createt we group by company an calculate the mean for the spread 
avg_spread = merged_data.groupby('Company')['Spread'].mean().reset_index()
avg_spread.rename(columns={'Spread': 'Average Spread'}, inplace=True) # For a more visuality we change the name of the column. 
print(avg_spread)

# Create the stripplot as seen in class asignments to deal with spreads and use seaborn for better visuality
plt.figure(figsize=(18, 11))
sns.stripplot(data=merged_data, x='Company', y='Spread',hue='Company', alpha=0.7, jitter=0.3, palette="viridis", legend=False)

# As we alerady have calculated the average spread, we decided to use it in this code. 
for index, row in avg_spread.iterrows():
    # As the average df gouped has diferent order from the merged data we use this code to map each company with their average. 
    x_index_pos = merged_data['Company'].unique().tolist().index(row['Company'])
    plt.text(x=x_index_pos, y=row['Average Spread'], s=f"{row['Average Spread']:.2f}", ha='center', va='bottom', fontsize=14, color='black', fontweight='bold')

# Details and customization for the plot 
plt.title('Daily Spread of Prices by Company', fontsize=14)
plt.xlabel('Company', fontsize=14)
plt.ylabel('Spread', fontsize=14)
plt.yscale('log')  # Logarithmic scale for comparability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
#   Company  Average Spread
# 0   BRK-A     1808.168152
# 1    DNUT        0.529063
# 2     DPZ        3.638052
# 3   LKNCY        1.114002
# 4     MCD        0.815206
# 5    PZZA        0.935416
# 6     QSR        1.207142
# 7    SBUX        0.610738
# 8     WEN        0.339679
# 9     YUM        0.886089
